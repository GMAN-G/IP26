# %%
# !python --version
# Out:
# Python 3.13.15

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/Colab26/images/곰.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x961>

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
